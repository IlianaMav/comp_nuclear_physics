# %%
import sympy as sp
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# ## Part A
#
# From eq.3 to eq.4

# %%
p = sp.Symbol('p')
pfe=sp.Symbol('pfe')
me=sp.Symbol('me')
n=sp.Symbol('n')
pi = sp.pi
xf=sp.Symbol('xf')
yf=sp.Symbol('yf')

# %%
constant = 1/(n * pi**2)

f = (p**2) * (sp.sqrt(p**2+me**2))

integral = sp.integrate(f, (p,0,pfe))

Ee = constant * integral

# %%
print('Integral=')
print(integral)
print('---------------------------------------------------------------------------------------------------------')
print('Ee=')
print(Ee)
# Out:
# Integral=
# -me**4*asinh(pfe/me)/8 + me**3*pfe/(8*sqrt(1 + pfe**2/me**2)) + 3*me*pfe**3/(8*sqrt(1 + pfe**2/me**2)) + pfe**5/(4*me*sqrt(1 + pfe**2/me**2))
# ---------------------------------------------------------------------------------------------------------
# Ee=
# (-me**4*asinh(pfe/me)/8 + me**3*pfe/(8*sqrt(1 + pfe**2/me**2)) + 3*me*pfe**3/(8*sqrt(1 + pfe**2/me**2)) + pfe**5/(4*me*sqrt(1 + pfe**2/me**2)))/(pi**2*n)

# %%
Ee = Ee.rewrite(sp.log)
print('Ee=')
print(Ee)
# Out:
# Ee=
# (-me**4*log(sqrt(1 + pfe**2/me**2) + pfe/me)/8 + me**3*pfe/(8*sqrt(1 + pfe**2/me**2)) + 3*me*pfe**3/(8*sqrt(1 + pfe**2/me**2)) + pfe**5/(4*me*sqrt(1 + pfe**2/me**2)))/(pi**2*n)

# %%
Ee= Ee.subs(pfe,me*xf)
print(Ee)
# Out:
# (me**4*xf**5/(4*sqrt(xf**2 + 1)) + 3*me**4*xf**3/(8*sqrt(xf**2 + 1)) + me**4*xf/(8*sqrt(xf**2 + 1)) - me**4*log(xf + sqrt(xf**2 + 1))/8)/(pi**2*n)

# %%
Ee =Ee.subs(sp.sqrt(1+xf**2),yf)
print(Ee)
# Out:
# (me**4*xf**5/(4*yf) + 3*me**4*xf**3/(8*yf) + me**4*xf/(8*yf) - me**4*log(xf + yf)/8)/(pi**2*n)

# %%
Ee = sp.factor(Ee)
print(Ee)
# Out:
# -me**4*(-2*xf**5 - 3*xf**3 - xf + yf*log(xf + yf))/(8*pi**2*n*yf)

# %%
sp.pprint(Ee)
# Out:
#    4 ⎛      5       3                       ⎞
# -me ⋅⎝- 2⋅xf  - 3⋅xf  - xf + yf⋅log(xf + yf)⎠
# ──────────────────────────────────────────────
#                      2
#                   8⋅π ⋅n⋅yf

# %% [markdown]
# ## Part B
#
# 1. From eq.19 to eq.21

# %%
mp = sp.Symbol('mp')
mn = sp.Symbol('mn')

a_v = sp.Symbol('a_v')
a_c = sp.Symbol('a_c')
a_s = sp.Symbol('a_s')
a_a = sp.Symbol('a_a')

x = sp.Symbol('x')
y = sp.Symbol('y')

# %%
f = mp*y + mn*(1-y) - a_v + (a_s/x) + a_c*x**2*y**2 + a_a*(1-2*y)**2
print(f)
# Out:
# a_a*(1 - 2*y)**2 + a_c*x**2*y**2 + a_s/x - a_v + mn*(1 - y) + mp*y

# %%
thetaf_x = sp.diff(f,x)
print('thetaf_x=')
print(thetaf_x)
# Out:
# thetaf_x=
# 2*a_c*x*y**2 - a_s/x**2

# %%
thetaf_y = sp.diff(f,y)
print('thetaf_y=')
print(thetaf_y)
# Out:
# thetaf_y=
# a_a*(8*y - 4) + 2*a_c*x**2*y - mn + mp

# %% [markdown]
# 2. Solve System of equations

# %%
solutions = sp.solve((thetaf_x,thetaf_y), (x,y))

for _,solution in enumerate(solutions):
    print(solution)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 solutions = sp.solve((thetaf_x,thetaf_y), (x,y))
#       3 for _,solution in enumerate(solutions):
#       4     print(solution)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\solvers.py:1170, in solve(f, *symbols, **flags)
#    1168         solution = _solve(f[0], *symbols, **flags)
#    1169 else:
# -> 1170     linear, solution = _solve_system(f, symbols, **flags)
#    1171 assert type(solution) is list
#    1172 assert not solution or type(solution[0]) is dict, solution
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\solvers.py:1892, in _solve_system(exprs, symbols, **flags)
#    1890 else:
#    1891     try:
# -> 1892         result = solve_poly_system(polys, *symbols)
#    1893         if result:
#    1894             solved_syms = symbols
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py:98, in solve_poly_system(seq, strict, *gens, **args)
#      95         except SolveFailed:
#      96             pass
# ---> 98 return solve_generic(polys, opt, strict=strict)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py:353, in solve_generic(polys, opt, strict)
#     350     return solutions
#     352 try:
# --> 353     result = _solve_reduced_system(polys, opt.gens, entry=True)
#     354 except CoercionFailed:
#     355     raise NotImplementedError
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py:342, in solve_generic.<locals>._solve_reduced_system(system, gens, entry)
#     339         if eq is not S.Zero:
#     340             new_system.append(eq)
# --> 342     for solution in _solve_reduced_system(new_system, new_gens):
#     343         solutions.append(solution + (zero,))
#     345 if solutions and len(solutions[0]) != len(gens):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py:290, in solve_generic.<locals>._solve_reduced_system(system, gens, entry)
#     286 """Recursively solves reduced polynomial systems. """
#     287 if len(system) == len(gens) == 1:
#     288     # the below line will produce UnsolvableFactorError if
#     289     # strict=True and the solution from `roots` is incomplete
# --> 290     zeros = list(roots(system[0], gens[-1], strict=strict).keys())
#     291     return [(zero,) for zero in zeros]
#     293 basis = groebner(system, gens, polys=True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polyroots.py:950, in roots(f, auto, cubics, trig, quartics, quintics, multiple, filter, predicate, strict, *gens, **flags)
#     948 else:
#     949     try:
# --> 950         F = Poly(f, *gens, **flags)
#     951         if not isinstance(f, Poly) and not F.gen.is_Symbol:
#     952             raise PolynomialError("generator must be a Symbol")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polytools.py:190, in Poly.__new__(cls, rep, *gens, **args)
#     188     return cls._from_poly(rep, opt)
#     189 else:
# --> 190     return cls._from_expr(rep, opt)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polytools.py:319, in Poly._from_expr(cls, rep, opt)
#     316 @classmethod
#     317 def _from_expr(cls, rep, opt):
#     318     """Construct a polynomial from an expression. """
# --> 319     rep, opt = _dict_from_expr(rep, opt)
#     320     return cls._from_dict(rep, opt)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polyutils.py:377, in _dict_from_expr(expr, opt)
#     375 if not isinstance(expr, (Expr, Eq)):
#     376     raise PolynomialError('expression must be of type Expr')
# --> 377 expr = expr.expand()
#     378 # TODO: Integrate this into expand() itself
#     379 while any(_is_expandable_pow(i) or i.is_Mul and
#     380     any(_is_expandable_pow(j) for j in i.args) for i in
#     381         Add.make_args(expr)):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py:3712, in Expr.expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3709     expr, _ = Expr._expand_hint(
#    3710         expr, '_eval_expand_multinomial', deep=deep, **hints)
#    3711 if hints.get('mul', False):
# -> 3712     expr, _ = Expr._expand_hint(
#    3713         expr, '_eval_expand_mul', deep=deep, **hints)
#    3714 if hints.get('log', False):
#    3715     expr, _ = Expr._expand_hint(
#    3716         expr, '_eval_expand_log', deep=deep, **hints)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py:3635, in Expr._expand_hint(expr, hint, deep, **hints)
#    3633 sargs = []
#    3634 for arg in expr.args:
# -> 3635     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3636     hit |= arghit
#    3637     sargs.append(arg)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py:3635, in Expr._expand_hint(expr, hint, deep, **hints)
#    3633 sargs = []
#    3634 for arg in expr.args:
# -> 3635     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3636     hit |= arghit
#    3637     sargs.append(arg)
#
#     [... skipping similar frames: Expr._expand_hint at line 3635 (13 times)]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py:3635, in Expr._expand_hint(expr, hint, deep, **hints)
#    3633 sargs = []
#    3634 for arg in expr.args:
# -> 3635     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3636     hit |= arghit
#    3637     sargs.append(arg)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py:3643, in Expr._expand_hint(expr, hint, deep, **hints)
#    3640         expr = expr.func(*sargs)
#    3642 if hasattr(expr, hint):
# -> 3643     newexpr = getattr(expr, hint)(**hints)
#    3644     if newexpr != expr:
#    3645         return (newexpr, True)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\mul.py:943, in Mul._eval_expand_mul(self, **hints)
#     941 n, d = fraction(expr, hints.get('exact', False))
#     942 if d.is_Mul:
# --> 943     n, d = [i._eval_expand_mul(**hints) if i.is_Mul else i
#     944         for i in (n, d)]
#     945 expr = n/d
#     946 if not expr.is_Mul:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\mul.py:943, in <listcomp>(.0)
#     941 n, d = fraction(expr, hints.get('exact', False))
#     942 if d.is_Mul:
# --> 943     n, d = [i._eval_expand_mul(**hints) if i.is_Mul else i
#     944         for i in (n, d)]
#     945 expr = n/d
#     946 if not expr.is_Mul:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\mul.py:969, in Mul._eval_expand_mul(self, **hints)
#     967 args = []
#     968 for term in terms:
# --> 969     t = self.func(plain, term)
#     970     if t.is_Mul and any(a.is_Add for a in t.args) and deep:
#     971         t = t._eval_expand_mul()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\cache.py:72, in __cacheit.<locals>.func_wrapper.<locals>.wrapper(*args, **kwargs)
#      69 @wraps(func)
#      70 def wrapper(*args, **kwargs):
#      71     try:
# ---> 72         retval = cfunc(*args, **kwargs)
#      73     except TypeError as e:
#      74         if not e.args or not e.args[0].startswith('unhashable type:'):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\operations.py:108, in AssocOp.__new__(cls, evaluate, _sympify, *args)
#     105 if len(args) == 1:
#     106     return args[0]
# --> 108 c_part, nc_part, order_symbols = cls.flatten(args)
#     109 is_commutative = not nc_part
#     110 obj = cls._from_args(c_part + nc_part, is_commutative)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\mul.py:722, in Mul.flatten(cls, seq)
#     719 c_part = _new
#     721 # order commutative part canonically
# --> 722 _mulsort(c_part)
#     724 # current code expects coeff to be always in slot-0
#     725 if coeff is not S.One:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\mul.py:36, in _mulsort(args)
#      34 def _mulsort(args):
#      35     # in-place sorting of args
# ---> 36     args.sort(key=_args_sortkey)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\basic.py:413, in Basic.compare(self, other)
#     411 for l, r in zip(st, ot):
#     412     if isinstance(l, Basic):
# --> 413         c = l.compare(r)
#     414     elif isinstance(l, frozenset):
#     415         l = Basic(*l) if isinstance(l, frozenset) else l
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\core\basic.py:366, in Basic.compare(self, other)
#     336     """
#     337     Return object `type` assumptions.
#     338
#    (...)
#     362      True, 'zero': False}
#     363     """
#     364     return {}
# --> 366 def compare(self, other):
#     367     """
#     368     Return -1, 0, 1 if the object is less than, equal,
#     369     or greater than other in a canonical sense.
#    (...)
#     392
#     393     """
#     394     # all redefinitions of __cmp__ method should start with the
#     395     # following lines:
#
# KeyboardInterrupt:

# %%
solutions = sp.nonlinsolve((thetaf_x,thetaf_y), (x,y))

for _,solution in enumerate(solutions):
    print(solution)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Owner\AppData\Local\Temp\ipykernel_27272\692372732.py", line 1, in <module>
#     solutions = sp.nonlinsolve((thetaf_x,thetaf_y), (x,y))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\solveset.py", line 4088, in nonlinsolve
#     poly_sol, poly_eqs = _handle_poly(polys, symbols)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\solveset.py", line 3867, in _handle_poly
#     result = solve_poly_system(basis, *symbols, strict=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py", line 98, in solve_poly_system
#     return solve_generic(polys, opt, strict=strict)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py", line 353, in solve_generic
#     result = _solve_reduced_system(polys, opt.gens, entry=True)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py", line 342, in _solve_reduced_system
#     for solution in _solve_reduced_system(new_system, new_gens):
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\polysys.py", line 290, in _solve_reduced_system
#     zeros = list(roots(system[0], gens[-1], strict=strict).keys())
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polyroots.py", line 950, in roots
#     F = Poly(f, *gens, **flags)
#         ^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polytools.py", line 190, in __new__
#     return cls._from_expr(rep, opt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polytools.py", line 319, in _from_expr
#     rep, opt = _dict_from_expr(rep, opt)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\polys\polyutils.py", line 377, in _dict_from_expr
#     expr = expr.expand()
#            ^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\core\cache.py", line 72, in wrapper
#     retval = cfunc(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py", line 3709, in expand
#     expr, _ = Expr._expand_hint(
#               ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py", line 3635, in _expand_hint
#     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py", line 3635, in _expand_hint
#     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py", line 3635, in _expand_hint
#     arg, arghit = Expr._expand_hint(arg, hint, **hints)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   [Previous line repeated 11 more times]
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\core\expr.py", line 3643, in _expand_hint
#     newexpr = getattr(expr, hint)(**hints)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\core\power.py", line 1103, in _eval_expand_multinomial
#     expansion_dict = multinomial_coefficients(len(p), n)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\sympy\ntheory\multinomial.py", line -1, in multinomial_coefficients
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\stack_data\utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\stack_data\core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "C:\Users\Owner\AppData\Roaming\Python\Python311\site-packages\executing\executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
params = {a_v:15.71511, a_s:17.53638, a_c:0.71363, a_a:23.37837}

solutions = sp.nsolve((thetaf_x.subs(params),thetaf_y.subs(params)), (x,y), (1,1))

for _,solution in enumerate(solutions):
    print(solution)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\mpmath\calculus\optimization.py:937, in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     936 try:
# --> 937     fx = f(*x0)
#     938     multidimensional = isinstance(fx, (list, tuple, ctx.matrix))
#
# File <lambdifygenerated-3>:2, in _lambdifygenerated(x, y)
#       1 def _lambdifygenerated(x, y):
# ----> 2     return ImmutableDenseMatrix([[mpf((0, 3213903802080407, -51, 52))*x*y**2 - mpf((0, 2468026076044607, -47, 52))/x**2], [-mn + mp + mpf((0, 3213903802080407, -51, 52))*x**2*y + mpf((0, 6580426151283099, -45, 53))*y + mpf((1, 6580426151283099, -46, 53))]])
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mpmath\matrices\matrices.py:302, in _matrix.__init__(self, *args, **kwargs)
#     300         for j, a in enumerate(row):
#     301             # note: this will call __setitem__ which will call self.ctx.convert() to convert the datatype.
# --> 302             self[i, j] = a
#     303 else:
#     304     # interpret list as row vector
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mpmath\matrices\matrices.py:560, in _matrix.__setitem__(self, key, value)
#     559 # Convert and store value
# --> 560 value = self.ctx.convert(value)
#     561 if value: # only store non-zeros
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mpmath\ctx_mp_python.py:671, in PythonMPContext.convert(ctx, x, strings)
#     670     except: pass
# --> 671 return ctx._convert_fallback(x, strings)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mpmath\ctx_mp.py:634, in MPContext._convert_fallback(ctx, x, strings)
#     633         raise ValueError("can only create mpf from zero-width interval")
# --> 634 raise TypeError("cannot create mpf from " + repr(x))
#
# TypeError: cannot create mpf from -mn + mp + 94.9407400000000012419
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 3
#       1 params = {a_v:15.71511, a_s:17.53638, a_c:0.71363, a_a:23.37837}
# ----> 3 solutions = sp.nsolve((thetaf_x.subs(params),thetaf_y.subs(params)), (x,y), (1,1))
#       5 for _,solution in enumerate(solutions):
#       6     print(solution)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\utilities\decorator.py:93, in conserve_mpmath_dps.<locals>.func_wrapper(*args, **kwargs)
#      91 dps = mpmath.mp.dps
#      92 try:
# ---> 93     return func(*args, **kwargs)
#      94 finally:
#      95     mpmath.mp.dps = dps
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\solvers.py:3100, in nsolve(dict, *args, **kwargs)
#    3098 J = lambdify(fargs, J, modules)
#    3099 # solve the system numerically
# -> 3100 x = findroot(f, x0, J=J, **kwargs)
#    3101 if as_dict:
#    3102     return [dict(zip(fargs, [sympify(xi) for xi in x]))]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mpmath\calculus\optimization.py:940, in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     938     multidimensional = isinstance(fx, (list, tuple, ctx.matrix))
#     939 except TypeError:
# --> 940     fx = f(x0[0])
#     941     multidimensional = False
#     942 if 'multidimensional' in kwargs:
#
# TypeError: _lambdifygenerated() missing 1 required positional argument: 'y'

# %%
eq1 = x**3 -(a_s/(2*a_c))*(1/y**2)
eq2 = y - (0.5)/(1+(a_c/4*a_a)*x**2)

params = {a_v:15.71511, a_s:17.53638, a_c:0.71363, a_a:23.37837}

solutions = sp.nsolve((eq1.subs(params), eq2.subs(params)), (x,y), (3.9, 0.4), tol=1e-6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 6
#       2 eq2 = y - (0.5)/(1+(a_c/4*a_a)*x**2)
#       4 params = {a_v:15.71511, a_s:17.53638, a_c:0.71363, a_a:23.37837}
# ----> 6 solutions = sp.nsolve((eq1.subs(params), eq2.subs(params)), (x,y), (3.9, 0.4), tol=1e-6)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\utilities\decorator.py:93, in conserve_mpmath_dps.<locals>.func_wrapper(*args, **kwargs)
#      91 dps = mpmath.mp.dps
#      92 try:
# ---> 93     return func(*args, **kwargs)
#      94 finally:
#      95     mpmath.mp.dps = dps
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sympy\solvers\solvers.py:3100, in nsolve(dict, *args, **kwargs)
#    3098 J = lambdify(fargs, J, modules)
#    3099 # solve the system numerically
# -> 3100 x = findroot(f, x0, J=J, **kwargs)
#    3101 if as_dict:
#    3102     return [dict(zip(fargs, [sympify(xi) for xi in x]))]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\mpmath\calculus\optimization.py:985, in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     983         xl = x
#     984     if verify and norm(f(*xl))**2 > tol: # TODO: better condition?
# --> 985         raise ValueError('Could not find root within given tolerance. '
#     986                          '(%s > %s)\n'
#     987                          'Try another starting point or tweak arguments.'
#     988                          % (norm(f(*xl))**2, tol))
#     989     return x
#     990 finally:
#
# ValueError: Could not find root within given tolerance. (223.604160885462404733 > 1e-06)
# Try another starting point or tweak arguments.

# %%
a_v=15.71511
a_s = 17.53638
a_c = 0.71363
a_a = 23.37837


def eq_system(p):

    x,y = p
    eq1 = x**3 -(a_s/(2*a_c))*(1/y**2)
    eq2 = y - (0.5)/(1+(a_c/4*a_a)*x**2)

    return [eq1,eq2]

solutions = fsolve(eq_system, [1,0.9])

x_0 = solutions[0]
y_0 = solutions[1]

print(f"x0= {x_0}")
print(f"y0= {y_0}")
# Out:
# x0= 4.708016756430452
# y0= 0.34312305426087375
# C:\Users\Owner\AppData\Local\Temp\ipykernel_27272\1200341264.py:15: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last five Jacobian evaluations.
#   solutions = fsolve(eq_system, [1,0.9])

# %% [markdown]
# With this format the equations during the calculations in the numerical solution are not going to infinity:

# %%
a_v=15.71511
a_s = 17.53638
a_c = 0.71363
a_a = 23.37837
delta_m = 1.3


def eq_system(p):

    x,y = p
    eq1 = 2*a_c*x*y**2 - a_s/x**2
    eq2 = a_a*(8*y - 4) + 2*a_c*x**2*y - delta_m

    return [eq1,eq2]

solutions = fsolve(eq_system, [1,1])

x_0 = solutions[0]
y_0 = solutions[1]

print(f"x0= {x_0}")
print(f"y0= {y_0}")

A_0 = x_0**3
Z_0 = y_0*A_0
N_0 = A_0 - Z_0

print(f"A0= {A_0}")
print(f"Z0= {Z_0}")
print(f"N0= {N_0}")
# Out:
# x0= 3.905899251254765
# y0= 0.45408470238209425
# A0= 59.58859021369053
# Z0= 27.058267252552238
# N0= 32.530322961138296

# %% [markdown]
# ## Part C

# %%
import numpy as np
from scipy.optimize import fsolve
import matplotlib.pyplot as plt

a_v = 15.71511
a_s = 17.53638
a_c = 0.71363
a_a = 23.37837
delta_m = 1.3
C_l = 0.001

def eq_system(p, p_F_val):
    x, y = p
    
    # Calculate c_l (Equation 27)
    a_c_tilde = a_c - C_l * p_F_val
    
    # To prevent errors
    if x <= 0 or y <= 0:
        return [1e6, 1e6]
        
    eq1 = 2 * a_c_tilde * x * y**2 - a_s / x**2
    eq2 = -delta_m + 2 * a_c_tilde * (x**2) * y - 4 * a_a * (1 - 2*y) + (y**(1/3)) * p_F_val
    
    return [eq1, eq2]

p_F_range = np.linspace(0, 40, 400)

x_solutions = []
y_solutions = []

# Initial guess for the very first iteration
current_guess = [4.0, 0.4]

# Loop through each p_F value
for p_F_val in p_F_range:
    # Solve using the last successful solution as the next initial guess
    sol, info, ier, msg = fsolve(eq_system, current_guess, args=(p_F_val,), full_output=True)
    
    if ier == 1:  # Solution converged successfully
        x_solutions.append(sol[0])
        y_solutions.append(sol[1])
        current_guess = [sol[0], sol[1]]  # Update guess for the next step
    else:
        # If it fails to converge, break the loop or append NaN to handle it gracefully
        x_solutions.append(np.nan)
        y_solutions.append(np.nan)

x_solutions_1 = np.array(x_solutions)
y_solutions_1 = np.array(y_solutions)

# %%
import numpy as np
from scipy.optimize import fsolve
import matplotlib.pyplot as plt

a_v = 15.71511
a_s = 17.53638
a_c = 0.71363
a_a = 23.37837
delta_m = 1.3
C_l = 0

def eq_system(p, p_F_val):
    x, y = p
    
    # Calculate c_l (Equation 27)
    a_c_tilde = a_c - C_l * p_F_val
    
    # To prevent errors
    if x <= 0 or y <= 0:
        return [1e6, 1e6]
        
    eq1 = 2 * a_c_tilde * x * y**2 - a_s / x**2
    eq2 = -delta_m + 2 * a_c_tilde * (x**2) * y - 4 * a_a * (1 - 2*y) + (y**(1/3)) * p_F_val
    
    return [eq1, eq2]

p_F_range = np.linspace(0, 40, 400)

x_solutions = []
y_solutions = []

# Initial guess for the very first iteration
current_guess = [4.0, 0.4]

# Loop through each p_F value
for p_F_val in p_F_range:
    # Solve using the last successful solution as the next initial guess
    sol, info, ier, msg = fsolve(eq_system, current_guess, args=(p_F_val,), full_output=True)
    
    if ier == 1:  # Solution converged successfully
        x_solutions.append(sol[0])
        y_solutions.append(sol[1])
        current_guess = [sol[0], sol[1]]  # Update guess for the next step
    else:
        # If it fails to converge, break the loop or append NaN to handle it gracefully
        x_solutions.append(np.nan)
        y_solutions.append(np.nan)

x_solutions_2 = np.array(x_solutions)
y_solutions_2 = np.array(y_solutions)

# %%
p_F_range = np.linspace(0, 40, 400)

x_linear = 3.90610 + 0.03023 * p_F_range
y_linear = 0.45405 - 0.00419 * p_F_range

# %%
plt.clf()
plt.figure(figsize=(8, 10))
plots = {
    'cl_1':{'x':x_solutions_1, 'y':y_solutions_1},
    'cl_2':{'x':x_solutions_2, 'y':y_solutions_2}
}

# Plot y
plt.subplot(2, 1, 1)
plt.plot(p_F_range, plots['cl_1']['y'], color='black', linewidth=2, label= 'cl=0.001')
plt.plot(p_F_range, plots['cl_2']['y'], color='red', linestyle=':',linewidth=2, label='cl=0')
plt.plot(p_F_range, y_linear, color='blue', linewidth=2, linestyle=':', label='Linear Approx (Eq. 29b)')
plt.xlabel('$p_F$')
plt.ylabel('$y$ = $Z/A$')
plt.title('$y$ as a function of $p_F$')
plt.grid(True)
plt.legend()

# Plot x
plt.subplot(2, 1, 2)
plt.plot(p_F_range, plots['cl_1']['x'], color='black', linewidth=2, label= 'cl=0.001')
plt.plot(p_F_range, plots['cl_2']['x'], color='red', linestyle=':',linewidth=2, label='cl=0')
plt.plot(p_F_range, x_linear, color='blue', linewidth=2, linestyle=':', label='Linear Approx (Eq. 29a)')
plt.xlabel('$p_F$')
plt.ylabel('$x$ = $A^{1/3}$')
plt.title('$x$ as a function of $p_F$')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
a_v = 15.71511
a_s = 17.53638
a_c = 0.71363
a_a = 23.37837
delta_m = 1.3
C_l = 0.001

hbar_c = 197.3269804     # MeV * fm
m_n = 1.674927471e-24
fm3_to_cm3 = 1e39


def pF_to_r(p_F):
    n = (p_F**3) / (3 * np.pi**2 * hbar_c**3)
    n = n * fm3_to_cm3
    r = n * m_n
    return r/1e11

p_F_values = np.linspace(1, 40, 400)
r_values = pF_to_r(p_F_values)


A_continuous = x_solutions_1**3
Z_continuous = y_solutions_1 * A_continuous

A_integer = np.round(A_continuous)
Z_integer = np.round(Z_continuous)
N_integer = A_integer - Z_integer

plt.figure(figsize=(10, 6))

plt.step(r_values, Z_integer, label='Protons ($Z$)', color='blue', linewidth=2)
plt.step(r_values, N_integer, label='Neutrons ($N$)', color='green', linewidth=2)

plt.xscale('log')
plt.xlim(1e-4, 1e1)

plt.ylim(20, 90)
plt.grid(True, which="both", ls="--", alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
